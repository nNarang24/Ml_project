# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model  ##scikit learn library

# %%
df=pd.read_csv('prices.csv')
df.head()
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  680000
# 4  4000       5.0    8  725000

# %%
plt.plot(df.area,df.price,color='green',linestyle='--', marker='o', label='growth')
plt.xlabel('area')
plt.ylabel('price')
plt.title('LINEAR REGRESSION USING SINGLE VARIABLE')
plt.grid(True)
plt.legend()
plt.show()

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)  ## x, y
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
plt.scatter(df.area,df.price,color='green',linestyle='--', marker='o', label='growth')
plt.xlabel('area')
plt.ylabel('price')
plt.title('LINEAR REGRESSION USING SINGLE VARIABLE')
plt.grid(True)
plt.plot(df.area,reg.predict(df[['area']]),color='red',label='regression')
plt.legend()
plt.show()

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
reg.predict([[5000]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
import pickle

# %%
##save model using pickle
with open('model_pickle','wb') as f:
  pickle.dump(reg,f)

# %%
r=pickle.load(open('model_pickle','rb'))

# %%
r.predict([[3300]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
d=pd.read_excel('areas.xlsx')

# %%
p=reg.predict(d)

# %%
d['price']=p

# %%
d.to_excel('predicted.xlsx')

# %%
##EXCERCISE
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('income.csv')
df.head()
# Out:
#    year        price
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
reg=LinearRegression()

# %%
reg.fit(df[['year']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
plt.scatter(df.year,df.price,color='green',linestyle='--', marker='o', label='growth')
plt.xlabel('year')
plt.ylabel('price')
plt.title('LINEAR REGRESSION USING SINGLE VARIABLE')
plt.grid(True)
plt.plot(df.year,reg.predict(df[['year']]),color='red',label='regression')

# %%
##mutiple linear regression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df=pd.read_csv('prices.csv')
df.head()
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  680000
# 4  4000       5.0    8  725000

# %%
df['new_bed']=df['bedrooms'].fillna(df['bedrooms'].mean())

# %%
df.head()
# Out:
#    area  bedrooms  age   price  new_bed
# 0  2600       3.0   20  550000     3.00
# 1  3000       4.0   15  565000     4.00
# 2  3200       NaN   18  610000     3.75
# 3  3600       3.0   30  680000     3.00
# 4  4000       5.0    8  725000     5.00

# %%
model=LinearRegression()
model.fit(df[['area','age','new_bed']],df.price)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([    214.10809916,   -8411.15590589, -112830.49521632])

# %%
model.predict[[]]

# %%
x=df.area
y=df.price

plt.scatter(x,y,color='green',linestyle='--', marker='o', label='growth')
plt.xlabel('x')
plt.ylabel('y')
plt.title('LINEAR REGRESSION USING MULTIPLE VARIABLE')
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2482124783.py in <cell line: 0>()
# ----> 1 x=df.area
#       2 y=df.price
#       3
#       4 plt.scatter(x,y,color='green',linestyle='--', marker='o', label='growth')
#       5 plt.xlabel('x')
#
# NameError: name 'df' is not defined

# %%
##GRADIENT DECSENT
import numpy as np
import pandas as pd
def gradient_descent(x,y):
    m_curr=b_curr=0
    iterations=1000
    n=len(x)
    learningRate=0.001
    for i in range(iterations):
      y_predicted=m_curr*x+b_curr
      md=-(2/n)*sum(x*(y-y_predicted))
      bd=-(2/n)*sum((y-y_predicted))
      m_curr=m_curr=learningRate*md
      b_curr=b_curr-learningRate*bd

      return m_curr,b_curr


x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# (np.float64(-0.062), np.float64(0.018000000000000002))

# %%
m,b=gradient_descent(x,y)
y_pred=m*x+b

plt.scatter(x, y, color='blue', label='Data Points')
plt.plot(x, y_pred, color='red', label=f'Best Fit Line: y={m:.2f}x+{b:.2f}')

# %%
##handling text datas
##label encoding->integer encoding and categorical variables
##ONE HOT ENCODING ->meaning we convert one value to 1 and cold 0,
##at a time only that particular value is 1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('car.csv')
df.head()
# Out:
#     model  Mileage  Sell Price($)  Age(yrs)
# 0  BMW X5    69000          18000         6
# 1  BMW X5    35000          34000         3
# 2  BMW X5    57000          26100         5
# 3  BMW X5    22500          40000         2
# 4  BMW X5    46000          31500         4

# %%
dummies=pd.get_dummies(df.model).astype(int)
dummies
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0         0       1                      0
# 1         0       1                      0
# 2         0       1                      0
# 3         0       1                      0
# 4         0       1                      0
# 5         1       0                      0
# 6         1       0                      0
# 7         1       0                      0
# 8         1       0                      0
# 9         0       0                      1
# 10        0       0                      1
# 11        0       0                      1
# 12        0       0                      1

# %%
merged=pd.concat([df,dummies],axis='columns')
merged
# Out:
#                     model  Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5  \
# 0                  BMW X5    69000          18000         6        0       1
# 1                  BMW X5    35000          34000         3        0       1
# 2                  BMW X5    57000          26100         5        0       1
# 3                  BMW X5    22500          40000         2        0       1
# 4                  BMW X5    46000          31500         4        0       1
# 5                 Audi A5    59000          29400         5        1       0
# 6                 Audi A5    52000          32000         5        1       0
# 7                 Audi A5    72000          19300         6        1       0
# 8                 Audi A5    91000          12000         8        1       0
# 9   Mercedez Benz C class    67000          22000         6        0       0
# 10  Mercedez Benz C class    83000          20000         7        0       0
# ...

# %%
final=merged.drop(['model'],axis='columns')
final
# Out:
#     Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5  Mercedez Benz C class
# 0     69000          18000         6        0       1                      0
# 1     35000          34000         3        0       1                      0
# 2     57000          26100         5        0       1                      0
# 3     22500          40000         2        0       1                      0
# 4     46000          31500         4        0       1                      0
# 5     59000          29400         5        1       0                      0
# 6     52000          32000         5        1       0                      0
# 7     72000          19300         6        1       0                      0
# 8     91000          12000         8        1       0                      0
# 9     67000          22000         6        0       0                      1
# 10    83000          20000         7        0       0                      1
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

X=df[['Mileage','Age(yrs)','AudiA5','BMW X5']]
y=df['price']

model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-102229636.py in <cell line: 0>()
#       2 model=LinearRegression()
#       3
# ----> 4 X=df[['Mileage','Age(yrs)','AudiA5','BMW X5']]
#       5 y=df['price']
#       6
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df1=df
df1.model=le.fit_transform(df1.model)

df1
# Out:
#     model  Mileage  Sell Price($)  Age(yrs)
# 0       1    69000          18000         6
# 1       1    35000          34000         3
# 2       1    57000          26100         5
# 3       1    22500          40000         2
# 4       1    46000          31500         4
# 5       0    59000          29400         5
# 6       0    52000          32000         5
# 7       0    72000          19300         6
# 8       0    91000          12000         8
# 9       2    67000          22000         6
# 10      2    83000          20000         7
# 11      2    79000          21000         7
# 12      2    59000          33000         5

# %%
X=df[['model','Mileage','Age(yrs)']].values
y=df['Sell Price($)']
X
# Out:
# array([[    1, 69000,     6],
#        [    1, 35000,     3],
#        [    1, 57000,     5],
#        [    1, 22500,     2],
#        [    1, 46000,     4],
#        [    0, 59000,     5],
#        [    0, 52000,     5],
#        [    0, 72000,     6],
#        [    0, 91000,     8],
#        [    2, 67000,     6],
#        [    2, 83000,     7],
#        [    2, 79000,     7],
#        [    2, 59000,     5]])

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
##Encoding categorical data values
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1, 3])], remainder='passthrough')
X = np.array(ct.fit_transform(X))


##handling missing data
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X[:, [2]])
X[:, [2]] = imputer.transform(X[:, [2]])

##ENCODING DEPENDET VARIABLE
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
Y = le.fit_transform(Y)

# %%
#testing and training dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('car.csv')
df
# Out:
#     mileage  price  age
# 0     69000  18000    6
# 1     35000  34000    3
# 2     57000  26100    5
# 3     22500  40000    2
# 4     46000  31500    4
# 5     59000  29400    5
# 6     52000  32000    5
# 7     72000  19300    6
# 8     91000  12000    8
# 9     67000  22000    6
# 10    83000  20000    7
# 11    79000  21000    7
# 12    59000  33000    5
# 13    67000  22000   12
# 14   100000  65000   10

# %%
plt.subplot(2,2,1)
plt.scatter(df['age'],df['price'])
plt.subplot(2,2,2)
plt.scatter(df['mileage'],df['price'])

# %%
x=df[['mileage','age']]
y=df['price']

# %%
x
# Out:
#     mileage  age
# 0     69000    6
# 1     35000    3
# 2     57000    5
# 3     22500    2
# 4     46000    4
# 5     59000    5
# 6     52000    5
# 7     72000    6
# 8     91000    8
# 9     67000    6
# 10    83000    7
# 11    79000    7
# 12    59000    5
# 13    67000   12
# 14   100000   10

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# 13    22000
# 14    65000
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
X_train
# Out:
#     mileage  age
# 6     52000    5
# 8     91000    8
# 2     57000    5
# 10    83000    7
# 5     59000    5
# 11    79000    7
# 14   100000   10
# 1     35000    3
# 0     69000    6
# 4     46000    4
# 13    67000   12
# 9     67000    6

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,Y_train)  ##model learns patterns from training data

##fit()= the model memorizes the relationship between x_train and y_train
# Out:
# LinearRegression()

# %%
model.predict(X_test)

##ANALOGY
# y_pred → predictions
# y_test → actual values (we compare these to see how accurate the model is)
# Out:
# array([24423.02520118, 27820.57205063, 26943.30923657])

# %%
Y_test
# Out:
# 3     40000
# 7     19300
# 12    33000
# Name: price, dtype: int64

# %%
model.score(X_test,Y_test) ##model is really bad
# Out:
# -0.5872055456728671

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('car.csv')
df.head()

x=df[['mileage','age']]
y=df['price']

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=10)

from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_prediction=model.predict(X_test)
y_prediction
# Out:
# array([34000, 20000, 20000])

# %%
model.score(X_test,Y_test)
# Out:
# 0.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.08109047, 0.09138542, 0.08490974, 0.08677109, 0.09489693,
#         0.09614711, 0.09543903, 0.09943683, 0.09721264, 0.10073925,
#         0.07197147],
#        [0.13868337, 0.10552164, 0.13913165, 0.11697892, 0.06054849,
#         0.08363877, 0.09237942, 0.06637972, 0.06372013, 0.04901131,
#         0.08400658],
#        [0.12106047, 0.10213701, 0.12143498, 0.10911968, 0.07293133,
#         0.08754991, 0.09330273, 0.07449449, 0.07323782, 0.05977353,
#         0.08495805]])
